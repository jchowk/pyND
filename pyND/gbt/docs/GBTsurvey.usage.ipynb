# %% [markdown]
# # Using `pyND.gbt.GBTsurvey`
#
# This code reads an entire survey from a GBTIDL FITS file.

# %%
# Typical imports here
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import astropy.constants as c

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pyND.gbt import *

# %% [markdown]
# ## Loading GBT spectra from GBTIDL ASCII output

# %%
input_filename = 'data/GBTdata.fits'
x = GBTsurvey.from_GBTIDL(input_filename)

# %%
x.index
# Out:
# <Table length=5>
#       object       idx  ...         RA               DEC
#       str17       int64 ...      float64           float64
# ----------------- ----- ... ----------------- -----------------
#       HS0033+4300     0 ... 9.095833333333333 43.27784722222222
#       HS0058+4213     1 ...         15.379875 42.49323888888889
# RXSJ0043.6+372521     2 ... 10.92708333333333 37.42194444444444
#         ZW535.012     3 ... 9.087166666666667 45.66478333333333
#        Q0030+3700     4 ... 7.572500000000001            37.015

# %% [markdown]
# ## Save to a pickle file

# %%
x.save2pickle('data/GBTdata.pkl')

# %% [markdown]
# ## Sort by latitude

# %%
x.sort('b')
x.index['b'].data
# Out:
# array([-25.66441146, -25.42430042, -20.33971225, -19.50893572,
#        -17.12615362])

# %%
x.sort('b',reverse=True)
x.index['b'].data
# Out:
# array([-17.12615362, -19.50893572, -20.33971225, -25.42430042,
#        -25.66441146])

# %% [markdown]
# ## Plot the first spectrum

# %%
x.survey[0].plotspectrum()

# %% [markdown]
# ## Plot all of the spectra

# %%
# for j in np.arange(len(x.index)):
#     x.survey[j].plotspectrum()

# %% [markdown]
# # Examining the metadata

# %%
x.data_file,x.GBTFITS_file
# Out:
# ('data/GBTdata.pkl',
#  '/Users/howk/Dropbox (KODIAQ)/python/pyND/gbt/docs/data/GBTdata.fits')

# %% [markdown]
# # Resample the velocity grid of the entire survey

# %%
x_new = x.copy()
new_velocity = np.arange(-400,100,5.)
x_new.resample_survey(new_velocity)

# %%
x.survey[0].plotspectrum()
x_new.survey[0].plotspectrum()

# %%
fig=plt.figure(figsize=(8,10))

ax1=fig.add_subplot(211)
ax1.plot(x.survey[0].velocity,x.survey[0].Tb,drawstyle='steps-mid',label='Original')
ax1.plot(x_new.survey[0].velocity,x_new.survey[0].Tb,
         drawstyle='steps-mid',label='Resampled',lw=3,zorder=0)

ax1.set_xlim(-200,50)
ax1.set_xlabel('Velocity')
ax1.set_ylabel('Tb [K]')
ax1.legend(loc='upper left',title=x.index['object'][0])

ax2=fig.add_subplot(212)
ax2.plot(x.survey[4].velocity,x.survey[4].Tb,drawstyle='steps-mid',
         label='Original[4]',lw=2,color='C2')
ax2.plot(x_new.survey[4].velocity,x_new.survey[4].Tb,
         drawstyle='steps-mid',zorder=0,
         label='Resampled[4]',lw=3,color='C3')

ax2.set_xlim(-200,50)
ax2.set_xlabel('Velocity')
ax2.set_ylabel('Tb [K]')
ax2.legend(loc='upper left',title=x.index['object'][4])

# %% [markdown]
# #### Check that we get the same column densities

# %%
j=0
print("Column densities -- Original: {0:0.3g}; Resampled: {1:0.3g}".format(x.survey[j].columndensity(),x_new.survey[j].columndensity()))
# Out:
# Column densities -- Original: 6.22e+20; Resampled: 6.22e+20

# %%
j=4
print("Column densities -- Original: {0:0.3g}; Resampled: {1:0.3g}".format(x.survey[j].columndensity(),x_new.survey[j].columndensity()))
# Out:
# Column densities -- Original: 5.52e+20; Resampled: 5.53e+20
